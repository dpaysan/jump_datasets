# %% [markdown]
# # Loading profiles from the JUMP Cell Painting Datasets
# This notebook loads a small number of plates with precomputed features and the metadata information.
# ## Import libraries

# %%
import io
import pandas as pd
import plotly.express as px
import plotly.io as pio
import numpy as np

pio.renderers.default = "notebook_connected"  # Set to "svg" or "png" for static plots or "notebook_connected" for interactive plots

# %% [markdown]
# ## Helper functions

# %%
profile_formatter = (
    "s3://cellpainting-gallery/cpg0016-jump/"
    "{Metadata_Source}/workspace/profiles/"
    "{Metadata_Batch}/{Metadata_Plate}/{Metadata_Plate}.parquet"
)

loaddata_formatter = (
    "s3://cellpainting-gallery/cpg0016-jump/"
    "{Metadata_Source}/workspace/load_data_csv/"
    "{Metadata_Batch}/{Metadata_Plate}/load_data_with_illum.parquet"
)

# %% [markdown]
# ## Load metadata
#
# The following files contain the metadata information for the entire dataset.
# The schema is [here](metadata/README.md).

# %%
plates = pd.read_csv("metadata/plate.csv")
wells = pd.read_csv("metadata/well.csv")
compound = pd.read_csv("metadata/compound.csv")
orf = pd.read_csv("metadata/orf.csv")

# %%
np.unique(plates.Metadata_PlateType)
# Out:
# array(['COMPOUND', 'COMPOUND_EMPTY', 'DMSO', 'ORF', 'POSCON8', 'TARGET1',
#        'TARGET2'], dtype=object)

# %% [markdown]
# ## Sample plates
# Let's sample two plates of a certain type (encoded in `Metadata_PlateType`) from each data-generating center (`Metadata_Source`). Note that only 10 out of the 13 sources are currently available and `source_1` does not have the plate type being queried below.

# %%
sample = (
    plates.query('Metadata_PlateType=="ORF"')
)
sample
# Out:
#      Metadata_Source      Metadata_Batch Metadata_Plate Metadata_PlateType
# 989         source_4   2021_04_26_Batch1     BR00117035                ORF
# 990         source_4   2021_04_26_Batch1     BR00117036                ORF
# 991         source_4   2021_04_26_Batch1     BR00117037                ORF
# 992         source_4   2021_04_26_Batch1     BR00117038                ORF
# 993         source_4   2021_04_26_Batch1     BR00117039                ORF
# ...              ...                 ...            ...                ...
# 1256        source_4  2021_08_30_Batch13     BR00124781                ORF
# 1257        source_4  2021_08_30_Batch13     BR00124782                ORF
# 1258        source_4  2021_08_30_Batch13     BR00126062                ORF
# 1259        source_4  2021_08_30_Batch13     BR00126404                ORF
# 1260        source_4  2021_08_30_Batch13     BR00126543                ORF
#
# [251 rows x 4 columns]

# %%
np.unique(sample.Metadata_Batch)
# Out:
# array(['2021_04_26_Batch1', '2021_05_10_Batch3', '2021_05_17_Batch4',
#        '2021_05_31_Batch2', '2021_06_07_Batch5', '2021_06_14_Batch6',
#        '2021_06_21_Batch7', '2021_07_12_Batch8', '2021_07_26_Batch9',
#        '2021_08_02_Batch10', '2021_08_09_Batch11', '2021_08_23_Batch12',
#        '2021_08_30_Batch13'], dtype=object)

# %% [markdown]
# `TARGET2` plates are "sentinel" plates that are run in each batch. More on all this in future updates.

# %% [markdown]
# ## Loading profiles
# Now let's load the profiles from these plates.
#
# Setting `columns = None` below will load all of the features.
#
# <div class="alert alert-warning">
# WARNING: Files are located in S3. This loop loads only two features per each sampled plate; loading many feature and/or many plates can take several minutes.
# </div>

# %%
dframes = []
# columns = [
#     "Metadata_Source",
#     "Metadata_Plate",
#     "Metadata_Well",
#     "Cells_AreaShape_Eccentricity",
#     "Nuclei_AreaShape_Area",
# ]
columns=None
for _, row in sample.iterrows():
    s3_path = profile_formatter.format(**row.to_dict())
    dframes.append(
        pd.read_parquet(s3_path, storage_options={"anon": True}, columns=columns)
    )
dframes = pd.concat(dframes)

# %%
len(dframes)
# Out:
# 9211

# %% [markdown]
# Each row in `dframes` is well-level profile, containing thousands of features (n=4762) averaged over (typically) a couple of thousand cells per well.

# %% [markdown]
# ## Join features with metadata
#
# The profiles are annotated with only three columns of metadata (source, plate, well).
#
# Let's add more metadata!

# %%
metadata = compound.merge(wells, on="Metadata_JCP2022")
ann_dframe = metadata.merge(
    dframes, on=["Metadata_Source", "Metadata_Plate", "Metadata_Well"]
)

# %% [markdown]
# We now know a little bit more about each profile:

# %%
ann_dframe.sample(2, random_state=42)
# Out:
#      Metadata_JCP2022            Metadata_InChIKey  \
# 8177   JCP2022_100264  WPEWQEMJFLWMLV-UHFFFAOYSA-N
# 6211   JCP2022_069491  PMATZTZNYRCHOR-UHFFFAOYSA-N
#
#                                          Metadata_InChI Metadata_Source  \
# 8177  InChI=1S/C24H23N5O/c25-17-24(11-1-2-12-24)19-5...        source_9
# 6211  InChI=1S/C62H111N11O12/c1-25-27-28-40(15)52(75...        source_9
#
#      Metadata_Plate Metadata_Well  Cells_AreaShape_Area  \
# 8177     GR00004371           Q11                3075.4
# 6211     GR00004371           M39                3131.2
#
#       Cells_AreaShape_BoundingBoxArea  Cells_AreaShape_BoundingBoxMaximum_X  \
# 8177                           5807.6                                582.32
# 6211                           5820.6                                558.59
#
#       Cells_AreaShape_BoundingBoxMaximum_Y  ...  \
# 8177                                606.96  ...
# 6211                                607.65  ...
#
#       Nuclei_Texture_Variance_RNA_10_02_256  \
# 8177                                 70.605
# 6211                                 71.894
#
#       Nuclei_Texture_Variance_RNA_10_03_256  \
# 8177                                 70.789
# 6211                                 69.011
#
#       Nuclei_Texture_Variance_RNA_3_00_256  \
# 8177                                66.448
# 6211                                66.948
#
#       Nuclei_Texture_Variance_RNA_3_01_256  \
# 8177                                66.704
# 6211                                66.677
#
#       Nuclei_Texture_Variance_RNA_3_02_256  \
# 8177                                66.121
# 6211                                66.121
#
#       Nuclei_Texture_Variance_RNA_3_03_256  \
# 8177                                66.668
# 6211                                67.140
#
#       Nuclei_Texture_Variance_RNA_5_00_256  \
# 8177                                67.195
# 6211                                67.972
#
#       Nuclei_Texture_Variance_RNA_5_01_256  \
# 8177                                68.803
# 6211                                69.008
#
#       Nuclei_Texture_Variance_RNA_5_02_256  \
# 8177                                66.839
# 6211                                67.207
#
#       Nuclei_Texture_Variance_RNA_5_03_256
# 8177                                68.641
# 6211                                69.256
#
# [2 rows x 4768 columns]

# %% [markdown]
# More metadata information will be added in the future.

# %% [markdown]
# ## Plot features
#
#
# The scatterplot below contains every well in the sampled dataset.
#
# In the interactive plot (see settings for `pio.renderers.default` above), you can hover over the points to see the JCP ID and the InChiKey for a given compound.
#
# <div class="alert alert-warning">
# NOTE: Because these are raw, unnormalized features, you will notice discernable clusters corresponding to each source due to batch effects.
# Upcoming data releases will included normalized features, where these effects are mitigated to some extent.
# </div>

# %%
from pickle import FALSE, TRUE

px.scatter(
    ann_dframe,
    x="Cells_AreaShape_Eccentricity",
    y="Nuclei_AreaShape_Area",
    color="Metadata_Source",
    hover_name="Metadata_JCP2022",
    hover_data=["Metadata_InChIKey"],
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c5c4fe2f-64f0-4c40-985c-acbd8fe1031c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5c4fe2f-64f0-4c40-985c-acbd8fe1031c")) {                    Plotly.newPlot(                        "c5c4fe2f-64f0-4c40-985c-acbd8fe1031c",                        [{"customdata":[["AECDBHGVIIRMOI-UHFFFAOYSA-N"],["AECDBHGVIIRMOI-UHFFFAOYSA-N"],["AFJRDFWMXUECEW-UHFFFAOYSA-N"],["AFJRDFWMXUECEW-UHFFFAOYSA-N"],["AFJRDFWMXUECEW-UHFFFAOYSA-N"],["AFJRDFWMXUECEW-UHFFFAOYSA-N"],["AGNWVEJTZJIJIM-UHFFFAOYSA-N"],["AGNWVEJTZJIJIM-UHFFFAOYSA-N"],["AJVXVYTVAAWZAP-UHFFFAOYSA-N"],["AJVXVYTVAAWZAP-UHFFFAOYSA-N"],["AJVXVYTVAAWZAP-UHFFFAOYSA-N"],["AJVXVYTVAAWZAP-UHFFFAOYSA-N"],["ALBKMJDFBZVHAK-UHFFFAOYSA-N"],["ALBKMJDFBZVHAK-UHFFFAOYSA-N"],["ALBKMJDFBZVHAK-UHFFFAOYSA-N"],["ALBKMJDFBZVHAK-UHFFFAOYSA-N"],["ALOBUEHUHMBRLE-UHFFFAOYSA-N"],["ALOBUEHUHMBRLE-UHFFFAOYSA-N"],["AUMHDRMJJNZTPB-UHFFFAOYSA-N"],["AUMHDRMJJNZTPB-UHFFFAOYSA-N"],["AYCPARAPKDAOEN-UHFFFAOYSA-N"],["AYCPARAPKDAOEN-UHFFFAOYSA-N"],["AYCPARAPKDAOEN-UHFFFAOYSA-N"],["AYCPARAPKDAOEN-UHFFFAOYSA-N"],["AZYDQCGCBQYFSE-UHFFFAOYSA-N"],["AZYDQCGCBQYFSE-UHFFFAOYSA-N"],["BBDGBGOVJPEFBT-UHFFFAOYSA-N"],["BBDGBGOVJPEFBT-UHFFFAOYSA-N"],["BCZUAADEACICHN-UHFFFAOYSA-N"],["BCZUAADEACICHN-UHFFFAOYSA-N"],["BDNFQGRSKSQXRI-UHFFFAOYSA-N"],["BDNFQGRSKSQXRI-UHFFFAOYSA-N"],["BGVLELSCIHASRV-UHFFFAOYSA-N"],["BGVLELSCIHASRV-UHFFFAOYSA-N"],["BLVQHYHDYFTPDV-UHFFFAOYSA-N"],["BLVQHYHDYFTPDV-UHFFFAOYSA-N"],["BNFRJXLZYUTIII-UHFFFAOYSA-N"],["BNFRJXLZYUTIII-UHFFFAOYSA-N"],["BOFQWVMAQOTZIW-UHFFFAOYSA-N"],["BOFQWVMAQOTZIW-UHFFFAOYSA-N"],["BYBLEWFAAKGYCD-UHFFFAOYSA-N"],["BYBLEWFAAKGYCD-UHFFFAOYSA-N"],["CANBMWXJDLUDFF-UHFFFAOYSA-N"],["CANBMWXJDLUDFF-UHFFFAOYSA-N"],["CAOWNCTTWGSKDO-UHFFFAOYSA-N"],["CAOWNCTTWGSKDO-UHFFFAOYSA-N"],["CDJNNOJINJAXPV-UHFFFAOYSA-N"],["CDJNNOJINJAXPV-UHFFFAOYSA-N"],["CDMGBJANTYXAIV-UHFFFAOYSA-N"],["CDMGBJANTYXAIV-UHFFFAOYSA-N"],["CEUORZQYGODEFX-UHFFFAOYSA-N"],["CEUORZQYGODEFX-UHFFFAOYSA-N"],["CKTSBUTUHBMZGZ-UHFFFAOYSA-N"],["CKTSBUTUHBMZGZ-UHFFFAOYSA-N"],["CMSMOCZEIVJLDB-UHFFFAOYSA-N"],["CMSMOCZEIVJLDB-UHFFFAOYSA-N"],["CMYHZFCJPORPHY-UHFFFAOYSA-N"],["CMYHZFCJPORPHY-UHFFFAOYSA-N"],["CQKBSRPVZZLCJE-UHFFFAOYSA-N"],["CQKBSRPVZZLCJE-UHFFFAOYSA-N"],["CUIHSIWYWATEQL-UHFFFAOYSA-N"],["CUIHSIWYWATEQL-UHFFFAOYSA-N"],["CWHUFRVAEUJCEF-UHFFFAOYSA-N"],["CWHUFRVAEUJCEF-UHFFFAOYSA-N"],["CWHUFRVAEUJCEF-UHFFFAOYSA-N"],["CWHUFRVAEUJCEF-UHFFFAOYSA-N"],["CXUCKELNYMZTRT-UHFFFAOYSA-N"],["CXUCKELNYMZTRT-UHFFFAOYSA-N"],["CYYNMPPFEJPBJD-UHFFFAOYSA-N"],["CYYNMPPFEJPBJD-UHFFFAOYSA-N"],["DHMTURDWPRKSOA-UHFFFAOYSA-N"],["DHMTURDWPRKSOA-UHFFFAOYSA-N"],["DHMTURDWPRKSOA-UHFFFAOYSA-N"],["DHMTURDWPRKSOA-UHFFFAOYSA-N"],["DJKJVWJQAVGLHJ-UHFFFAOYSA-N"],["DJKJVWJQAVGLHJ-UHFFFAOYSA-N"],["DMWVGXGXHPOEPT-UHFFFAOYSA-N"],["DMWVGXGXHPOEPT-UHFFFAOYSA-N"],["DPJNKUOXBZSZAI-UHFFFAOYSA-N"],["DPJNKUOXBZSZAI-UHFFFAOYSA-N"],["DSLRVRBSNLHVBH-UHFFFAOYSA-N"],["DSLRVRBSNLHVBH-UHFFFAOYSA-N"],["DTGLZDAWLRGWQN-UHFFFAOYSA-N"],["DTGLZDAWLRGWQN-UHFFFAOYSA-N"],["DUKQPWDVIZDABV-UHFFFAOYSA-N"],["DUKQPWDVIZDABV-UHFFFAOYSA-N"],["DXZRBHUCOHBAHP-UHFFFAOYSA-N"],["DXZRBHUCOHBAHP-UHFFFAOYSA-N"],["FABUFPQFXZVHFB-UHFFFAOYSA-N"],["FABUFPQFXZVHFB-UHFFFAOYSA-N"],["FERIUCNNQQJTOY-UHFFFAOYSA-N"],["FERIUCNNQQJTOY-UHFFFAOYSA-N"],["FHPOTBQOUBMMCI-UHFFFAOYSA-N"],["FHPOTBQOUBMMCI-UHFFFAOYSA-N"],["FMYGNANMYYHBSU-UHFFFAOYSA-N"],["FMYGNANMYYHBSU-UHFFFAOYSA-N"],["FNHKPVJBJVTLMP-UHFFFAOYSA-N"],["FNHKPVJBJVTLMP-UHFFFAOYSA-N"],["FNYLWPVRPXGIIP-UHFFFAOYSA-N"],["FNYLWPVRPXGIIP-UHFFFAOYSA-N"],["FPVKHBSQESCIEP-UHFFFAOYSA-N"],["FPVKHBSQESCIEP-UHFFFAOYSA-N"],["FQUAFMNPXPXOJE-UHFFFAOYSA-N"],["FQUAFMNPXPXOJE-UHFFFAOYSA-N"],["FYIBXBFDXNPBSF-UHFFFAOYSA-N"],["FYIBXBFDXNPBSF-UHFFFAOYSA-N"],["GCUCIFQCGJIRNT-UHFFFAOYSA-N"],["GCUCIFQCGJIRNT-UHFFFAOYSA-N" ...

# %% [markdown]
# So that's just a couple of (raw) measurements from the sentinel plates for 10/13 of the sources, for the principal dataset alone.

# %% [markdown]
# ## Load images
#
# [LoadData](https://cellprofiler-manual.s3.amazonaws.com/CPmanual/LoadData.html) CSV files provide Metadata associated with the images to be processed.

# %%
load_data = []
for _, row in sample.iterrows():
    s3_path = loaddata_formatter.format(**row.to_dict())
    load_data.append(pd.read_parquet(s3_path, storage_options={"anon": True}))
load_data = pd.concat(load_data)

# %% [markdown]
# Let's pick a row at random and inspect it

# %%
sample_loaddata = load_data.sample(1, random_state=42)
pd.melt(sample_loaddata)
# Out:
#               variable                                              value
# 0      Metadata_Source                                           source_4
# 1       Metadata_Batch                                 2021_08_02_Batch10
# 2       Metadata_Plate                                         BR00121423
# 3        Metadata_Well                                                C18
# 4        Metadata_Site                                                  2
# 5    FileName_IllumAGP                            BR00121423_IllumAGP.npy
# 6    FileName_IllumDNA                            BR00121423_IllumDNA.npy
# 7     FileName_IllumER                             BR00121423_IllumER.npy
# 8   FileName_IllumMito                           BR00121423_IllumMito.npy
# 9    FileName_IllumRNA                            BR00121423_IllumRNA.npy
# 10    FileName_OrigAGP                     r03c18f02p01-ch2sk1fk1fl1.tiff
# 11    FileName_OrigDNA                     r03c18f02p01-ch5sk1fk1fl1.tiff
# 12     FileName_OrigER                     r03c18f02p01-ch4sk1fk1fl1.tiff
# 13   FileName_OrigMito                     r03c18f02p01-ch1sk1fk1fl1.tiff
# 14    FileName_OrigRNA                     r03c18f02p01-ch3sk1fk1fl1.tiff
# 15   PathName_IllumAGP  s3://cellpainting-gallery/cpg0016-jump/source_...
# 16   PathName_IllumDNA  s3://cellpainting-gallery/cpg0016-jump/source_...
# 17    PathName_IllumER  s3://cellpainting-gallery/cpg0016-jump/source_...
# 18  PathName_IllumMito  s3://cellpainting-gallery/cpg0016-jump/source_...
# 19   PathName_IllumRNA  s3://cellpainting-gallery/cpg0016-jump/source_...
# 20    PathName_OrigAGP  s3://cellpainting-gallery/cpg0016-jump/source_...
# 21    PathName_OrigDNA  s3://cellpainting-gallery/cpg0016-jump/source_...
# 22     PathName_OrigER  s3://cellpainting-gallery/cpg0016-jump/source_...
# 23   PathName_OrigMito  s3://cellpainting-gallery/cpg0016-jump/source_...
# 24    PathName_OrigRNA  s3://cellpainting-gallery/cpg0016-jump/source_...

# %% [markdown]
# The `Metadata_` columns can be used to link the images to profiles.
# Let's pick a profile and view it's corresponding image.

# %%
sample_profile = ann_dframe.sample(1, random_state=22)
sample_profile.melt()
# Out:
#                        variable  \
# 0              Metadata_JCP2022
# 1             Metadata_InChIKey
# 2                Metadata_InChI
# 3               Metadata_Source
# 4                Metadata_Plate
# 5                 Metadata_Well
# 6  Cells_AreaShape_Eccentricity
# 7         Nuclei_AreaShape_Area
#
#                                                value
# 0                                     JCP2022_075916
# 1                        QUGDTMONBLMLLD-UHFFFAOYSA-N
# 2  InChI=1S/C9H13N5O/c1-3-14-8-6(7(10)11-5-12-8)1...
# 3                                           source_8
# 4                                           A1166179
# 5                                                P17
# 6                                            0.79228
# 7                                             747.66

# %% [markdown]
# First link the profile to it's images.
# These are well-level profiles, and each well has typically 9 sites imaged.

# %%
sample_linked = pd.merge(
    load_data, sample_profile, on=["Metadata_Source", "Metadata_Plate", "Metadata_Well"]
)
sample_linked[['Metadata_Well', 'Metadata_Site']]
# Out:
#   Metadata_Well Metadata_Site
# 0           P17             1
# 1           P17             2
# 2           P17             3
# 3           P17             4
# 4           P17             5
# 5           P17             6
# 6           P17             7
# 7           P17             8
# 8           P17             9

# %% [markdown]
# Inspect details of a single site for this profile

# %%
sample_linked.iloc[:1].melt()
# Out:
#                         variable  \
# 0                Metadata_Source
# 1                 Metadata_Batch
# 2                 Metadata_Plate
# 3                  Metadata_Well
# 4                  Metadata_Site
# 5              FileName_IllumAGP
# 6              FileName_IllumDNA
# 7               FileName_IllumER
# 8             FileName_IllumMito
# 9              FileName_IllumRNA
# 10              FileName_OrigAGP
# 11              FileName_OrigDNA
# 12               FileName_OrigER
# 13             FileName_OrigMito
# 14              FileName_OrigRNA
# 15             PathName_IllumAGP
# 16             PathName_IllumDNA
# 17              PathName_IllumER
# 18            PathName_IllumMito
# 19             PathName_IllumRNA
# 20              PathName_OrigAGP
# 21              PathName_OrigDNA
# 22               PathName_OrigER
# 23             PathName_OrigMito
# 24              PathName_OrigRNA
# 25              Metadata_JCP2022
# 26             Metadata_InChIKey
# 27                Metadata_InChI
# 28  Cells_AreaShape_Eccentricity
# 29         Nuclei_AreaShape_Area
#
#                                                 value
# 0                                            source_8
# 1                                                  J4
# 2                                            A1166179
# 3                                                 P17
# 4                                                   1
# 5                               A1166179_IllumAGP.npy
# 6                               A1166179_IllumDNA.npy
# 7                                A1166179_IllumER.npy
# 8                              A1166179_IllumMito.npy
# 9                               A1166179_IllumRNA.npy
# 10  HTS_P17_s1_w2A2101C33-E43F-436C-AE2C-9896DBB20...
# 11  HTS_P17_s1_w580635C7E-1CBF-462D-A37D-AB2CE387F...
# 12  HTS_P17_s1_w473ACB338-DC97-4A0F-9DA2-33A7CFB1E...
# 13  HTS_P17_s1_w1111E149D-7DBE-4B30-93D4-67B9741E2...
# 14  HTS_P17_s1_w3EEB30122-92BB-4981-85F3-131C2C508...
# 15  s3://cellpainting-gallery/cpg0016-jump/source_...
# 16  s3://cellpainting-gallery/cpg0016-jump/source_...
# 17  s3://cellpainting-gallery/cpg0016-jump/source_...
# 18  s3://cellpainting-gallery/cpg0016-jump/source_...
# 19  s3://cellpainting-gallery/cpg0016-jump/source_...
# 20  s3://cellpainting-gallery/cpg0016-jump/source_...
# 21  s3://cellpainting-gallery/cpg0016-jump/source_...
# 22  s3://cellpainting-gallery/cpg0016-jump/source_...
# 23  s3://cellpainting-gallery/cpg0016-jump/source_...
# 24  s3://cellpainting-gallery/cpg0016-jump/source_...
# 25                                     JCP2022_075916
# 26                        QUGDTMONBLMLLD-UHFFFAOYSA-N
# 27  InChI=1S/C9H13N5O/c1-3-14-8-6(7(10)11-5-12-8)1...
# 28                                            0.79228
# 29                                             747.66

# %% [markdown]
# Now load and display a single channel of this 5-channel image

# %%
import os
import requests
from io import BytesIO
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import boto3

image_url = os.path.join(
    sample_linked.iloc[0].PathName_OrigDNA, sample_linked.iloc[0].FileName_OrigDNA
)
s3_client = boto3.client("s3")
response = s3_client.get_object(
    Bucket=image_url.split("/")[2], Key="/".join(image_url.split("/")[3:])
)
image = mpimg.imread(BytesIO(response["Body"].read()), format="tiff")

plt.imshow(image, cmap="gray")
image_url
# Out:
# 's3://cellpainting-gallery/cpg0016-jump/source_8/images/J4/images/A1166179/Images/HTS_P17_s1_w580635C7E-1CBF-462D-A37D-AB2CE387F9BA.tif'

# %% [markdown]
# There's a lot more to come! We will add more example notebooks as we go.
