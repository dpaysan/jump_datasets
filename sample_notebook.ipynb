# %% [markdown]
# # Loading profiles from the JUMP Cell Painting Datasets
# This notebook loads a small number of plates with precomputed features and the metadata information.
# ## Import libraries

# %%
import io
import pandas as pd
import plotly.express as px
import plotly.io as pio
import numpy as np

pio.renderers.default = "notebook_connected"  # Set to "svg" or "png" for static plots or "notebook_connected" for interactive plots

# %% [markdown]
# ## Helper functions

# %%
profile_formatter = (
    "s3://cellpainting-gallery/cpg0016-jump/"
    "{Metadata_Source}/workspace/profiles/"
    "{Metadata_Batch}/{Metadata_Plate}/{Metadata_Plate}.parquet"
)

loaddata_formatter = (
    "s3://cellpainting-gallery/cpg0016-jump/"
    "{Metadata_Source}/workspace/load_data_csv/"
    "{Metadata_Batch}/{Metadata_Plate}/load_data_with_illum.parquet"
)

# %% [markdown]
# ## Load metadata
#
# The following files contain the metadata information for the entire dataset.
# The schema is [here](metadata/README.md).

# %%
plates = pd.read_csv("metadata/plate.csv")
wells = pd.read_csv("metadata/well.csv")
compound = pd.read_csv("metadata/compound.csv")
orf = pd.read_csv("metadata/orf.csv")

# %%
np.unique(plates.Metadata_PlateType)
# Out:
# array(['COMPOUND', 'COMPOUND_EMPTY', 'DMSO', 'ORF', 'POSCON8', 'TARGET1',
#        'TARGET2'], dtype=object)

# %% [markdown]
# ## Sample plates
# Let's sample two plates of a certain type (encoded in `Metadata_PlateType`) from each data-generating center (`Metadata_Source`). Note that only 10 out of the 13 sources are currently available and `source_1` does not have the plate type being queried below.

# %%
sample = (
    plates.query('Metadata_PlateType=="ORF"')
)
sample
# Out:
#      Metadata_Source      Metadata_Batch Metadata_Plate Metadata_PlateType
# 989         source_4   2021_04_26_Batch1     BR00117035                ORF
# 990         source_4   2021_04_26_Batch1     BR00117036                ORF
# 991         source_4   2021_04_26_Batch1     BR00117037                ORF
# 992         source_4   2021_04_26_Batch1     BR00117038                ORF
# 993         source_4   2021_04_26_Batch1     BR00117039                ORF
# ...              ...                 ...            ...                ...
# 1256        source_4  2021_08_30_Batch13     BR00124781                ORF
# 1257        source_4  2021_08_30_Batch13     BR00124782                ORF
# 1258        source_4  2021_08_30_Batch13     BR00126062                ORF
# 1259        source_4  2021_08_30_Batch13     BR00126404                ORF
# 1260        source_4  2021_08_30_Batch13     BR00126543                ORF
#
# [251 rows x 4 columns]

# %%
np.unique(sample.Metadata_Batch)
# Out:
# array(['2021_04_26_Batch1', '2021_05_10_Batch3', '2021_05_17_Batch4',
#        '2021_05_31_Batch2', '2021_06_07_Batch5', '2021_06_14_Batch6',
#        '2021_06_21_Batch7', '2021_07_12_Batch8', '2021_07_26_Batch9',
#        '2021_08_02_Batch10', '2021_08_09_Batch11', '2021_08_23_Batch12',
#        '2021_08_30_Batch13'], dtype=object)

# %% [markdown]
# `TARGET2` plates are "sentinel" plates that are run in each batch. More on all this in future updates.

# %% [markdown]
# ## Loading profiles
# Now let's load the profiles from these plates.
#
# Setting `columns = None` below will load all of the features.
#
# <div class="alert alert-warning">
# WARNING: Files are located in S3. This loop loads only two features per each sampled plate; loading many feature and/or many plates can take several minutes.
# </div>

# %%
dframes = []
columns = [
    "Metadata_Source",
    "Metadata_Plate",
    "Metadata_Well",
    "Cells_AreaShape_Eccentricity",
    "Nuclei_AreaShape_Area",
]
for _, row in sample.iterrows():
    s3_path = profile_formatter.format(**row.to_dict())
    dframes.append(
        pd.read_parquet(s3_path, storage_options={"anon": True}, columns=columns)
    )
dframes = pd.concat(dframes)

# %%
len(dframes)
# Out:
# 768

# %% [markdown]
# Each row in `dframes` is well-level profile, containing thousands of features (n=4762) averaged over (typically) a couple of thousand cells per well.

# %% [markdown]
# ## Join features with metadata
#
# The profiles are annotated with only three columns of metadata (source, plate, well).
#
# Let's add more metadata!

# %%
metadata = compound.merge(wells, on="Metadata_JCP2022")
ann_dframe = metadata.merge(
    dframes, on=["Metadata_Source", "Metadata_Plate", "Metadata_Well"]
)

# %% [markdown]
# We now know a little bit more about each profile:

# %%
ann_dframe.sample(2, random_state=42)
# Out:
#    Metadata_JCP2022 Metadata_InChIKey Metadata_InChI Metadata_Source  \
# 29   JCP2022_999999               NaN            NaN        source_4
# 15   JCP2022_999999               NaN            NaN        source_4
#
#    Metadata_Plate Metadata_Well  Cells_AreaShape_Eccentricity  \
# 29     BR00126709           O22                       0.78466
# 15    BR00123528B           L21                       0.78240
#
#     Nuclei_AreaShape_Area
# 29                 1055.0
# 15                 1107.5

# %% [markdown]
# More metadata information will be added in the future.

# %% [markdown]
# ## Plot features
#
#
# The scatterplot below contains every well in the sampled dataset.
#
# In the interactive plot (see settings for `pio.renderers.default` above), you can hover over the points to see the JCP ID and the InChiKey for a given compound.
#
# <div class="alert alert-warning">
# NOTE: Because these are raw, unnormalized features, you will notice discernable clusters corresponding to each source due to batch effects.
# Upcoming data releases will included normalized features, where these effects are mitigated to some extent.
# </div>

# %%
from pickle import FALSE, TRUE

px.scatter(
    ann_dframe,
    x="Cells_AreaShape_Eccentricity",
    y="Nuclei_AreaShape_Area",
    color="Metadata_Source",
    hover_name="Metadata_JCP2022",
    hover_data=["Metadata_InChIKey"],
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6fd226de-db82-41ae-b2f7-c58800d1634d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd226de-db82-41ae-b2f7-c58800d1634d")) {                    Plotly.newPlot(                        "6fd226de-db82-41ae-b2f7-c58800d1634d",                        [{"customdata":[["CQKBSRPVZZLCJE-UHFFFAOYSA-N"],["CQKBSRPVZZLCJE-UHFFFAOYSA-N"],["IHLVSLOZUHKNMQ-UHFFFAOYSA-N"],["IHLVSLOZUHKNMQ-UHFFFAOYSA-N"],["IVUGFMLRJOCGAS-UHFFFAOYSA-N"],["IVUGFMLRJOCGAS-UHFFFAOYSA-N"],["LOUPRKONTZGTKE-UHFFFAOYSA-N"],["LOUPRKONTZGTKE-UHFFFAOYSA-N"],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null]],"hovertemplate":"<b>%{hovertext}</b><br><br>Metadata_Source=source_4<br>Cells_AreaShape_Eccentricity=%{x}<br>Nuclei_AreaShape_Area=%{y}<br>Metadata_InChIKey=%{customdata[0]}<extra></extra>","hovertext":["JCP2022_012818","JCP2022_012818","JCP2022_035095","JCP2022_035095","JCP2022_037716","JCP2022_037716","JCP2022_050797","JCP2022_050797","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999","JCP2022_999999"],"legendgroup":"source_4","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"source_4","orientation":"v","showlegend":true,"x":[0.73059,0.77879,0.75991,0.79646,0.74599,0.75748,0.77745,0.79855,0.78004,0.78089,0.78642,0.78201,0.78079,0.77676,0.78694,0.7824,0.77307,0.76663,0.76668,0.78183,0.79929,0.80244,0.79325,0.77912,0.77961,0.73253,0.77428,0.79866,0.78095,0.78466,0.79017,0.7899],"xaxis":"x","y":[1201.4,1198.8,1186.9,1059.7,1933.3,1804.8,1058.0,1054.9,1040.2,1092.3,1029.5,1025.0,1045.8,1013.0,1048.0,1107.5,1076.8,1030.4,1085.8,1028.0,1086.3,1063.8,1068.6,1046.9,1012.5,860.9,1038.2,1062.1,1077.3,1055.0,1084.3,1097.6],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"], ...

# %% [markdown]
# So that's just a couple of (raw) measurements from the sentinel plates for 10/13 of the sources, for the principal dataset alone.

# %% [markdown]
# ## Load images
#
# [LoadData](https://cellprofiler-manual.s3.amazonaws.com/CPmanual/LoadData.html) CSV files provide Metadata associated with the images to be processed.

# %%
sample = sample.sample(2)
load_data = []
for _, row in sample.iterrows():
    s3_path = loaddata_formatter.format(**row.to_dict())
    load_data.append(pd.read_parquet(s3_path, storage_options={"anon": True}))
load_data = pd.concat(load_data)

# %% [markdown]
# Let's pick a row at random and inspect it

# %%
sample_loaddata = load_data.sample(1, random_state=42)
pd.melt(sample_loaddata)
# Out:
#               variable                                              value
# 0      Metadata_Source                                           source_4
# 1       Metadata_Batch                                 2021_08_23_Batch12
# 2       Metadata_Plate                                         BR00126709
# 3        Metadata_Well                                                K05
# 4        Metadata_Site                                                  7
# 5    FileName_IllumAGP                            BR00126709_IllumAGP.npy
# 6    FileName_IllumDNA                            BR00126709_IllumDNA.npy
# 7     FileName_IllumER                             BR00126709_IllumER.npy
# 8   FileName_IllumMito                           BR00126709_IllumMito.npy
# 9    FileName_IllumRNA                            BR00126709_IllumRNA.npy
# 10    FileName_OrigAGP                     r11c05f07p01-ch2sk1fk1fl1.tiff
# 11    FileName_OrigDNA                     r11c05f07p01-ch5sk1fk1fl1.tiff
# 12     FileName_OrigER                     r11c05f07p01-ch4sk1fk1fl1.tiff
# 13   FileName_OrigMito                     r11c05f07p01-ch1sk1fk1fl1.tiff
# 14    FileName_OrigRNA                     r11c05f07p01-ch3sk1fk1fl1.tiff
# 15   PathName_IllumAGP  s3://cellpainting-gallery/cpg0016-jump/source_...
# 16   PathName_IllumDNA  s3://cellpainting-gallery/cpg0016-jump/source_...
# 17    PathName_IllumER  s3://cellpainting-gallery/cpg0016-jump/source_...
# 18  PathName_IllumMito  s3://cellpainting-gallery/cpg0016-jump/source_...
# 19   PathName_IllumRNA  s3://cellpainting-gallery/cpg0016-jump/source_...
# 20    PathName_OrigAGP  s3://cellpainting-gallery/cpg0016-jump/source_...
# 21    PathName_OrigDNA  s3://cellpainting-gallery/cpg0016-jump/source_...
# 22     PathName_OrigER  s3://cellpainting-gallery/cpg0016-jump/source_...
# 23   PathName_OrigMito  s3://cellpainting-gallery/cpg0016-jump/source_...
# 24    PathName_OrigRNA  s3://cellpainting-gallery/cpg0016-jump/source_...

# %% [markdown]
# The `Metadata_` columns can be used to link the images to profiles.
# Let's pick a profile and view it's corresponding image.

# %%
sample_profile = ann_dframe.sample(1, random_state=22)
sample_profile.melt()
# Out:
#                        variable           value
# 0              Metadata_JCP2022  JCP2022_999999
# 1             Metadata_InChIKey             NaN
# 2                Metadata_InChI             NaN
# 3               Metadata_Source        source_4
# 4                Metadata_Plate      BR00126709
# 5                 Metadata_Well             O21
# 6  Cells_AreaShape_Eccentricity         0.78095
# 7         Nuclei_AreaShape_Area          1077.3

# %% [markdown]
# First link the profile to it's images.
# These are well-level profiles, and each well has typically 9 sites imaged.

# %%
sample_linked = pd.merge(
    load_data, sample_profile, on=["Metadata_Source", "Metadata_Plate", "Metadata_Well"]
)
sample_linked[['Metadata_Well', 'Metadata_Site']]
# Out:
#   Metadata_Well Metadata_Site
# 0           O21             1
# 1           O21             2
# 2           O21             3
# 3           O21             4
# 4           O21             5
# 5           O21             6
# 6           O21             7
# 7           O21             8
# 8           O21             9

# %% [markdown]
# Inspect details of a single site for this profile

# %%
sample_linked.iloc[:1].melt()
# Out:
#                         variable  \
# 0                Metadata_Source
# 1                 Metadata_Batch
# 2                 Metadata_Plate
# 3                  Metadata_Well
# 4                  Metadata_Site
# 5              FileName_IllumAGP
# 6              FileName_IllumDNA
# 7               FileName_IllumER
# 8             FileName_IllumMito
# 9              FileName_IllumRNA
# 10              FileName_OrigAGP
# 11              FileName_OrigDNA
# 12               FileName_OrigER
# 13             FileName_OrigMito
# 14              FileName_OrigRNA
# 15             PathName_IllumAGP
# 16             PathName_IllumDNA
# 17              PathName_IllumER
# 18            PathName_IllumMito
# 19             PathName_IllumRNA
# 20              PathName_OrigAGP
# 21              PathName_OrigDNA
# 22               PathName_OrigER
# 23             PathName_OrigMito
# 24              PathName_OrigRNA
# 25              Metadata_JCP2022
# 26             Metadata_InChIKey
# 27                Metadata_InChI
# 28  Cells_AreaShape_Eccentricity
# 29         Nuclei_AreaShape_Area
#
#                                                 value
# 0                                            source_4
# 1                                  2021_08_23_Batch12
# 2                                          BR00126709
# 3                                                 O21
# 4                                                   1
# 5                             BR00126709_IllumAGP.npy
# 6                             BR00126709_IllumDNA.npy
# 7                              BR00126709_IllumER.npy
# 8                            BR00126709_IllumMito.npy
# 9                             BR00126709_IllumRNA.npy
# 10                     r15c21f01p01-ch2sk1fk1fl1.tiff
# 11                     r15c21f01p01-ch5sk1fk1fl1.tiff
# 12                     r15c21f01p01-ch4sk1fk1fl1.tiff
# 13                     r15c21f01p01-ch1sk1fk1fl1.tiff
# 14                     r15c21f01p01-ch3sk1fk1fl1.tiff
# 15  s3://cellpainting-gallery/cpg0016-jump/source_...
# 16  s3://cellpainting-gallery/cpg0016-jump/source_...
# 17  s3://cellpainting-gallery/cpg0016-jump/source_...
# 18  s3://cellpainting-gallery/cpg0016-jump/source_...
# 19  s3://cellpainting-gallery/cpg0016-jump/source_...
# 20  s3://cellpainting-gallery/cpg0016-jump/source_...
# 21  s3://cellpainting-gallery/cpg0016-jump/source_...
# 22  s3://cellpainting-gallery/cpg0016-jump/source_...
# 23  s3://cellpainting-gallery/cpg0016-jump/source_...
# 24  s3://cellpainting-gallery/cpg0016-jump/source_...
# 25                                     JCP2022_999999
# 26                                                NaN
# 27                                                NaN
# 28                                            0.78095
# 29                                             1077.3

# %% [markdown]
# Now load and display a single channel of this 5-channel image

# %%
import os
import requests
from io import BytesIO
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import boto3

image_url = os.path.join(
    sample_linked.iloc[0].PathName_OrigDNA, sample_linked.iloc[0].FileName_OrigDNA
)
print(image_url)
s3_client = boto3.client("s3")
response = s3_client.get_object(
    Bucket=image_url.split("/")[2], Key="/".join(image_url.split("/")[3:])
)
image = mpimg.imread(BytesIO(response["Body"].read()), format="tiff")

plt.imshow(image, cmap="gray")
image_url
# Out:
# s3://cellpainting-gallery/cpg0016-jump/source_4/images/2021_08_23_Batch12/images/BR00126709__2021-09-02T03_20_56-Measurement1/Images/r15c21f01p01-ch5sk1fk1fl1.tiff
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[24], line 13
#      11 print(image_url)
#      12 s3_client = boto3.client("s3")
# ---> 13 response = s3_client.get_object(
#      14     Bucket=image_url.split("/")[2], Key="/".join(image_url.split("/")[3:])
#      15 )
#      16 image = mpimg.imread(BytesIO(response["Body"].read()), format="tiff")
#      18 plt.imshow(image, cmap="gray")
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/client.py:508, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     504     raise TypeError(
#     505         f"{py_operation_name}() only accepts keyword arguments."
#     506     )
#     507 # The "self" in this scope is referring to the BaseClient.
# --> 508 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/client.py:898, in BaseClient._make_api_call(self, operation_name, api_params)
#     896 else:
#     897     apply_request_checksum(request_dict)
# --> 898     http, parsed_response = self._make_request(
#     899         operation_model, request_dict, request_context
#     900     )
#     902 self.meta.events.emit(
#     903     'after-call.{service_id}.{operation_name}'.format(
#     904         service_id=service_id, operation_name=operation_name
#    (...)
#     909     context=request_context,
#     910 )
#     912 if http.status_code >= 300:
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/client.py:921, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#     919 def _make_request(self, operation_model, request_dict, request_context):
#     920     try:
# --> 921         return self._endpoint.make_request(operation_model, request_dict)
#     922     except Exception as e:
#     923         self.meta.events.emit(
#     924             'after-call-error.{service_id}.{operation_name}'.format(
#     925                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     929             context=request_context,
#     930         )
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/endpoint.py:198, in Endpoint._send_request(self, request_dict, operation_model)
#     196 context = request_dict['context']
#     197 self._update_retries_context(context, attempts)
# --> 198 request = self.create_request(request_dict, operation_model)
#     199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#     202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#    (...)
#     207     exception,
#     208 ):
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/endpoint.py:134, in Endpoint.create_request(self, params, operation_model)
#     130     service_id = operation_model.service_model.service_id.hyphenize()
#     131     event_name = 'request-created.{service_id}.{op_name}'.format(
#     132         service_id=service_id, op_name=operation_model.name
#     133     )
# --> 134     self._event_emitter.emit(
#     135         event_name,
#     136         request=request,
#     137         operation_name=operation_model.name,
#     138     )
#     139 prepared_request = self.prepare_request(request)
#     140 return prepared_request
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/signers.py:103, in RequestSigner.handler(self, operation_name, request, **kwargs)
#      98 def handler(self, operation_name=None, request=None, **kwargs):
#      99     # This is typically hooked up to the "request-created" event
#     100     # from a client's event emitter.  When a new request is created
#     101     # this method is invoked to sign the request.
#     102     # Don't call this method directly.
# --> 103     return self.sign(operation_name, request)
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/signers.py:187, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     184     else:
#     185         raise e
# --> 187 auth.add_auth(request)
#
# File ~/miniconda3/envs/jump/lib/python3.10/site-packages/botocore/auth.py:407, in SigV4Auth.add_auth(self, request)
#     405 def add_auth(self, request):
#     406     if self.credentials is None:
# --> 407         raise NoCredentialsError()
#     408     datetime_now = datetime.datetime.utcnow()
#     409     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %% [markdown]
# There's a lot more to come! We will add more example notebooks as we go.
